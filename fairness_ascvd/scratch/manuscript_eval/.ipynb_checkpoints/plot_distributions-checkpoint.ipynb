# %%
import pandas as pd
import os
import numpy as np
import logging
import sys
import torch
import copy
import yaml
import random

from prediction_utils.pytorch_utils.metrics import (
    StandardEvaluator,
    FairOVAEvaluator,
    CalibrationEvaluator
)

import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
sns.set_style("ticks")


args = {'cohort_path': '/labs/shahlab/projects/agataf/data/cohorts/pooled_cohorts/cohort/all_cohorts.csv',
        'base_path': '/labs/shahlab/projects/agataf/data/cohorts/pooled_cohorts',
        'grp_label_dict': {1: 'Black women', 2: 'White women', 3: 'Black men', 4: 'White men', 'overall': 'Overall'},
        'plot_path': os.path.join('/labs/shahlab/projects/agataf/fairness_utility/eval_manuscript/plots', 'paper_plots'),

       }

output_path = os.path.join(args['plot_path'], 'risk_category_counts.png')
os.makedirs(args['plot_path'], exist_ok=True)

# %%
args['grp_label_dict']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-c84be7af07e4> in <module>
# ----> 1 args['grp_label_dict']
#
# KeyError: 'grp_label_dict'

# %%
args['grp_label_dict']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-c84be7af07e4> in <module>
# ----> 1 args['grp_label_dict']
#
# KeyError: 'grp_label_dict'

# %%
def get_frac_treated(df, add_strata=None):
    base_grouping = ['model_type', 'model_id','labels'] 
    if add_strata:
        base_grouping.append(add_strata)
    num_treated_by_stratum = (df
         .query('(phase=="test")')
         .filter(['person_id', 'treat'] + base_grouping)
         .groupby(['treat'] + base_grouping)
         .count()
        )

    num_per_stratum = (df
          .query('(phase=="test")')
               .filter(['person_id'] + base_grouping)
               .groupby(base_grouping)
               .count()
         )

    frac_treated = num_treated_by_stratum.div(num_per_stratum)


    return frac_treated.reset_index()

# %%
group_names = {'overall': 'overall',
               1: 'Black Women', 
               2: 'White Women', 
               3: 'Black Men', 
               4: 'White Men'
              }

model_type_names = {'original_pce': 'PCE',
                    'revised_pce': 'rPCE',
                    'erm': 'BL',
                    'recalib_erm': 'rBL',
                    'eqodds_thr': 'EO'
                   }

# %%
frac_treated_all = []
all_preds = []
eqodds_threshold = [0.1, 1]
for experiment in ['original_pce', 'revised_pce', 'apr14_erm', 'apr14_erm_recalib', 'apr14_thr']:

    aggregate_path = os.path.join(args['base_path'], 'experiments', 
                                      experiment, 'performance',
                                      'all')
    preds_path = os.path.join(aggregate_path, 'predictions.csv')
    preds = pd.read_csv(preds_path)
    
    if experiment in ['apr14_mmd', 'apr14_thr']:
        preds = preds.query('model_id == @eqodds_threshold')
        
    if 'model_id' not in preds.columns:
        preds = preds.assign(model_id=0)
    all_preds.append(preds)
    
all_preds = pd.concat(all_preds)
all_preds = all_preds.assign(#model_type=model_type,
                             group = lambda x: x.group.map(group_names),
                            model_type = lambda x: x.model_type.map(model_type_names))

model_type = np.where((all_preds.model_type=='EO') & (all_preds.model_id==0.1), 'mEO', all_preds.model_type)
model_type = np.where((all_preds.model_type=='EO') & (all_preds.model_id==1.0), 'sEO', model_type)


all_preds = all_preds.assign(model_type = pd.Categorical(model_type, 
                      categories=['PCE', 'rPCE', 'BL', 'rBL', 'mEO', 'sEO'],
                      ordered=True))


#     frac_treated = get_frac_treated(preds, add_strata='group') 
#     frac_treated_overall = get_frac_treated(preds, add_strata=None).assign(group='overall')
#     frac_treated = frac_treated.append(frac_treated_overall)
#     frac_treated = (frac_treated
#                     .assign(group = lambda x: x.group.map(args['grp_label_dict']),
#                             labels = lambda x: x.labels.map({0: ' Individuals with \nno ASCVD event',
#                                                              1: 'Individuals with \n  ASCVD event'}))
#                     .rename(columns={'person_id': 'fraction'})
#                    )
#     frac_treated_all.append(frac_treated)

# frac_treated_all = (pd
#                     .concat(frac_treated_all)
#                     .assign(model_type = lambda x: x.model_type.map({'original_pce': 'PCE',
#                                                                      'revised_pce': 'rPCE',
#                                                                      'erm': 'BL',
#                                                                      'recalib_erm': 'rBL',
#                                                                      'eqodds_thr': 'EO',
#                                                                     }
#                                                                    )
#                            )
#                    )



# model_type = np.where((frac_treated_all.model_type=='EO') & (frac_treated_all.model_id==0.1), 'mEO', frac_treated_all.model_type)
# model_type = np.where((frac_treated_all.model_type=='EO') & (frac_treated_all.model_id==1.0), 'sEO', model_type)

# frac_treated_all = frac_treated_all.assign(model_type=model_type)

# %%
all_preds.model_type.unique()
# Out:
# array(['original_pce', 'revised_pce', 'erm', 'recalib_erm', 'mEO', 'sEO'],
#       dtype=object)

# %%
all_preds.head()
# Out:
#   phase  pred_probs  labels   weights        group model_type  person_id  \
# 0     9    0.005016       0  1.069459  White Women        PCE          0
# 1     1    0.015671       0  1.069459  White Women        PCE          1
# 2     2    0.016608       0  1.069459  White Women        PCE          2
# 3  test    0.017007       0  1.069459  White Women        PCE          3
# 4     5    0.123553       0  1.069459  White Women        PCE          4
#
#    treat  relative_risk model_id  outputs  ldlc  fold_id  config_id
# 0      0       1.000000        0      NaN   NaN      NaN        NaN
# 1      0       1.000000        0      NaN   NaN      NaN        NaN
# 2      0       1.000000        0      NaN   NaN      NaN        NaN
# 3      0       1.000000        0      NaN   NaN      NaN        NaN
# 4      1       0.771363        0      NaN   NaN      NaN        NaN

# %%
all_preds.weights
# Out:
# 0         1.069459
# 1         1.069459
# 2         1.069459
# 3         1.069459
# 4         1.069459
#             ...
# 654735    1.132407
# 654736    1.122530
# 654737    1.126947
# 654738    1.034370
# 654739    1.138947
# Name: weights, Length: 270980, dtype: float64

# %%
#ordered_days = tips.day.value_counts().index
sns.despine(left=True)

sns.set(font_scale=1)
sns.set_style("whitegrid", {'grid.linestyle': '--'})
g = sns.FacetGrid(all_preds, 
                  col="group", 
                  row = "model_type",
                  hue='labels',
                  height=3, aspect=1.2,
                 margin_titles=True)
g.map(sns.kdeplot, 
      "pred_probs",
     # weights="weights"
     )

(g.set_xlabels('predicted risk')
 .set_ylabels('')
 .set_titles(row_template="{row_name}", col_template="{col_name}")
 #.set_yticklabels()
)
g.set(xlim=(0, 0.8))
axes = g.axes.flatten()
for ax in axes:
    ax.axvline(0.075, ls='--', linewidth=2, color='grey')
    ax.axvline(0.2, ls='--', linewidth=2, color='grey')

# %%
sns.despine(left=True)

sns.set(font_scale=1)
sns.set_style("ticks")
    
#all_preds1=all_preds.query("phase=='test' & model_type == ['erm', 'mEO', 'sEO']") 
f, axes = plt.subplots(len(all_preds.model_type.unique()),4, figsize=(len(all_preds.model_type.unique())*4, 20), sharex=False, sharey=False)
palette = iter(sns.color_palette("tab10",n_colors=len(all_preds.model_type.unique())))
#indices = {0: (0,0), 1: (1,0), 2: (0,1), 3: (1,1)}

axes_plotted = []
for idx_m, model_type in enumerate(all_preds.model_type.unique()):
    color=next(palette)
    for idx, grp in enumerate(range(1,5)):
        args_plt = {'shade': False, 
                #'label': config_id, 
                'ax': axes[idx_m,idx], 
                #'color':color
               }
        ax = sns.kdeplot(data=all_preds.query("model_type==@model_type & group==@grp & labels==1"), 
                         x="pred_probs",
                         weights="weights",
                         **args_plt,
                         linestyle="--")
        ax = sns.kdeplot(data=all_preds.query("model_type==@model_type & group==@grp & labels==0"), 
                         x="pred_probs",
                         weights="weights",
                         **args_plt,
                         legend=True)
        
        axes_plotted.append(ax)
        
        ax.set(xlim=(-0.1,1))
        ax.set(ylim=(0,17.5))
        ax.set_title(args['grp_label_dict'][grp])
        ax.set_xlabel("")
        ax.axvline(x=0.075, linestyle='--', color='grey')
        ax.axvline(x=0.2, linestyle='--', color='grey')

sns.set(font_scale=1)
