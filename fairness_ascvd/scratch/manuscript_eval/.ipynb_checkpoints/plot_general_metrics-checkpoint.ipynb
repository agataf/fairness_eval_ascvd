# %%
import pandas as pd
import os
import numpy as np

import seaborn as sns; sns.set()
sns.set_style("ticks")
import matplotlib.pyplot as plt

custom_palette = ["red", "green", "orange", "blue", "black"]
sns.set_palette(custom_palette)

calib_method = 'logx_logreg'


args = {'cohort_path': '/labs/shahlab/projects/agataf/data/cohorts/pooled_cohorts/cohort/all_cohorts.csv',
        'base_path': '/labs/shahlab/projects/agataf/data/cohorts/pooled_cohorts',
        'plot_path': os.path.join('/labs/shahlab/projects/agataf/fairness_utility/eval_manuscript/plots', 'paper_plots'),
        'eval_fold':  'eval',
        'grp_label_dict': {1: 'Black women', 2: 'White women', 3: 'Black men', 4: 'White men', 'overall': 'Overall'} 
       }
os.makedirs(args['plot_path'], exist_ok=True)

save_plots=True

# %%
aggregate_path_all = '/labs/shahlab/projects/agataf/data/cohorts/pooled_cohorts/experiments/bmj_manuscript/'

plot_df_all = pd.read_csv(os.path.join(aggregate_path_all, 'bootstrap_standard_eval.csv'))

# %%
metric_names = {'auc':                    'AUC', 
                'auprc':                  'AUPRC',
                'ace_rmse_logistic_log':  'ACE',
                'loss_bce':               'loss',
                'sensitivity':           'Sensitivity',
                'specificity':           'Specificity',
                'impl_threshold': 'Implied threshold',
                'impl_threshold threshold': 'Implied threshold',
                
               }

group_names = {'overall': 'overall',
               '1': 'Black Women', 
               '2': 'White Women', 
               '3': 'Black Men', 
               '4': 'White Men'
              }


plot_df = (plot_df_all.assign(metric = lambda x: x.metric.map(metric_names),
                              group = lambda x: x.group.map(group_names))
           .query("model_type != ['EO1', 'EO2', 'EO4']")
           .replace({'EO3': 'EO'})
           .assign(model_type = lambda x: pd.Categorical(x.model_type, 
                                                         categories=['PCE', 'rPCE', 'BL', 'rBL', 'EO'],
                                                         ordered=True))
          )

# %%
plot_df
# Out:
#     phase model_type        group             metric  CI_lower    CI_med  \
# 80   test         EO  Black Women                AUC  0.776244  0.839691
# 81   test         EO  Black Women              AUPRC  0.166852  0.291866
# 82   test         EO  Black Women  Implied threshold  0.012305  0.028147
# 83   test         EO  Black Women  Implied threshold  0.260076  0.424987
# 84   test         EO  Black Women        Sensitivity  0.727859  0.899129
# ..    ...        ...          ...                ...       ...       ...
# 315  test       rPCE      overall  Implied threshold  0.193913  0.212018
# 316  test       rPCE      overall        Sensitivity  0.686246  0.748802
# 317  test       rPCE      overall        Sensitivity  0.196179  0.256634
# 318  test       rPCE      overall        Specificity  0.706874  0.724595
# 319  test       rPCE      overall        Specificity  0.943622  0.951989
#
#      CI_upper  thresholds
# 80   0.896075         NaN
# 81   0.453957         NaN
# 82   0.044098       0.075
# 83   0.624644       0.200
# 84   1.000000       0.075
# ..        ...         ...
# 315  0.234159       0.200
# 316  0.808279       0.075
# 317  0.322879       0.200
# 318  0.740462       0.075
# 319  0.959807       0.200
#
# [200 rows x 8 columns]

# %%
g = sns.FacetGrid(to_plot, hue="group", col="metric", height=9,
                 palette = custom_palette)

#g = sns.FacetGrid(attend, col="subject", col_wrap=4, height=2, ylim=(0, 10))
g.map(sns.pointplot, "model_type", "CI_med", order = ['PCE', 'rPCE', 'BL', 'rBL', 'EO'], join=False, dodge=10)


# g=sns.relplot(data = to_plot,
#                 x = 'model_type',
#                 y = 'CI_med',
#                 col='metric',
#                 kind = 'line',
#                 palette = custom_palette, 
#                 hue='group',
#                 #err_style="bars",
#                 facet_kws= {'sharey': False, 'margin_titles': True},
#                 #err_kws = {'capsize': 5},
#                 legend=False,
#                 aspect=1,
#               marker='X',
#               markersize=14,
#                 linestyle='')



#fig, ax = plt.subplots()
#ax.errorbar(x=to_plot.model_type, y=to_plot.CI_med, yerr=[to_plot.CI_lower, to_plot.CI_upper], fmt='x')

# g=sns.pointplot(x="model_type", y="CI_med", hue="group", join=False,
#              # yerr=["CI_lower", "CI_upper"],
#                    data=to_plot, dodge=0.4, legend=False)

#g.map(plt.errorbar, "model_type", "CI_med", "CI_lower", marker="o")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-db9a76f77493> in <module>
#       3
#       4 #g = sns.FacetGrid(attend, col="subject", col_wrap=4, height=2, ylim=(0, 10))
# ----> 5 g.map(sns.pointplot, "model_type", "CI_med", order = ['PCE', 'rPCE', 'BL', 'rBL', 'EO'], join=False, dodge=10, hue="group")
#       6
#       7
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     682
#     683             # Draw the plot
# --> 684             self._facet_plot(func, ax, plot_args, kwargs)
#     685
#     686         # Finalize the annotations and layout
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     772                 plot_kwargs[key] = val
#     773             plot_args = []
# --> 774         func(*plot_args, **plot_kwargs)
#     775
#     776         # Sort out the supporting information
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/seaborn/categorical.py in pointplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize, ax, **kwargs)
#    3360 ):
#    3361
# -> 3362     plotter = _PointPlotter(x, y, hue, data, order, hue_order,
#    3363                             estimator, ci, n_boot, units, seed,
#    3364                             markers, linestyles, dodge, join, scale,
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, markers, linestyles, dodge, join, scale, orient, color, palette, errwidth, capsize)
#    1653                  orient, color, palette, errwidth=None, capsize=None):
#    1654         """Initialize the plotter."""
# -> 1655         self.establish_variables(x, y, hue, data, orient,
#    1656                                  order, hue_order, units)
#    1657         self.establish_colors(color, palette, 1)
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'group'

# %%
sns.set(font_scale=1.7)
sns.set_style("ticks")

to_plot = (plot_df
           .query("(metric == 'Sensitivity') & (thresholds == 0.075)")
#            .assign(metric = pd.Categorical(to_plot.metric, 
#                                            categories=['Sensitivity'],
#                                            ordered=True)
                  #)
          )



g=sns.relplot(data = to_plot,
                x = 'model_type',
                y = 'CI_med',
                col='metric',
                kind = 'line',
                palette = custom_palette, 
                hue='group',
                #err_style="bars",
                facet_kws= {'sharey': False, 'margin_titles': True},
                #err_kws = {'capsize': 5},
                legend=False,
                aspect=1,
              marker='X',
              markersize=14,
                linestyle='')



#fig, ax = plt.subplots()
#ax.errorbar(x=to_plot.model_type, y=to_plot.CI_med, yerr=[to_plot.CI_lower, to_plot.CI_upper], fmt='x')

# g=sns.pointplot(x="model_type", y="CI_med", hue="group", join=False,
#              # yerr=["CI_lower", "CI_upper"],
#                    data=to_plot, dodge=0.4, legend=False)

g.map(plt.errorbar, "model_type", "CI_med", "CI_lower", marker="o")

#asymmetric_error = to_plot.set_index(['group', 'model_type']).filter(['CI_lower', 'CI_upper'])
#axes = g.axes.flatten()
#g.errorbar(x=to_plot.model_type, y=to_plot.CI_med, yerr=[to_plot.CI_lower, to_plot.CI_upper], fmt='x')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-ca63dbfcd62d> in <module>
#      37 #                    data=to_plot, dodge=0.4, legend=False)
#      38
# ---> 39 g.map(plt.errorbar, "model_type", "CI_med", "CI_lower", marker="o")
#      40
#      41 #asymmetric_error = to_plot.set_index(['group', 'model_type']).filter(['CI_lower', 'CI_upper'])
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/seaborn/axisgrid.py in map(self, func, *args, **kwargs)
#     672
#     673             # Get the actual data we are going to plot with
# --> 674             plot_data = data_ijk[list(args)]
#     675             if self._dropna:
#     676                 plot_data = plot_data.dropna()
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1296             if missing == len(indexer):
#    1297                 axis_name = self.obj._get_axis_name(axis)
# -> 1298                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1299
#    1300             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['model_type', 'CI_med', 'CI_lower'], dtype='object')] are in the [columns]"

# %%
to_plot
# Out:
#     phase model_type        group       metric  CI_lower    CI_med  CI_upper  \
# 84   test         EO  Black Women  Sensitivity  0.727859  0.899129  1.000000
# 92   test         EO  White Women  Sensitivity  0.813859  0.917371  1.000000
# 100  test         EO    Black Men  Sensitivity  0.743310  0.903388  1.000000
# 108  test         EO    White Men  Sensitivity  0.792838  0.889175  0.972540
# 116  test         EO      overall  Sensitivity  0.824333  0.889747  0.977894
# 164  test         BL  Black Women  Sensitivity  0.653769  0.794652  0.932574
# 172  test         BL  White Women  Sensitivity  0.687766  0.812450  0.916959
# 180  test         BL    Black Men  Sensitivity  0.648727  0.809526  0.935933
# 188  test         BL    White Men  Sensitivity  0.766327  0.849672  0.931140
# 196  test         BL      overall  Sensitivity  0.767304  0.823074  0.874361
# 204  test        PCE  Black Women  Sensitivity  0.690137  0.828325  0.964304
# 212  test        PCE  White Women  Sensitivity  0.706363  0.812572  0.916875
# 220  test        PCE    Black Men  Sensitivity  0.902901  0.967883  1.000000
# 228  test        PCE    White Men  Sensitivity  0.888765  0.945088  0.986627
# 236  test        PCE      overall  Sensitivity  0.850327  0.895332  0.934148
# 244  test        rBL  Black Women  Sensitivity  0.622572  0.791346  0.931643
# 252  test        rBL  White Women  Sensitivity  0.623383  0.748953  0.855055
# 260  test        rBL    Black Men  Sensitivity  0.616592  0.778766  0.906551
# 268  test        rBL    White Men  Sensitivity  0.726475  0.822726  0.904501
# 276  test        rBL      overall  Sensitivity  0.725418  0.786251  0.841727
# 284  test       rPCE  Black Women  Sensitivity  0.557404  0.725939  0.895377
# 292  test       rPCE  White Women  Sensitivity  0.457536  0.602219  0.731121
# 300  test       rPCE    Black Men  Sensitivity  0.709493  0.840919  0.938836
# 308  test       rPCE    White Men  Sensitivity  0.713252  0.809321  0.903401
# 316  test       rPCE      overall  Sensitivity  0.686246  0.748802  0.808279
#
#      thresholds
# 84        0.075
# 92        0.075
# 100       0.075
# 108       0.075
# 116       0.075
# 164       0.075
# 172       0.075
# 180       0.075
# 188       0.075
# 196       0.075
# 204       0.075
# 212       0.075
# 220       0.075
# 228       0.075
# 236       0.075
# 244       0.075
# 252       0.075
# 260       0.075
# 268       0.075
# 276       0.075
# 284       0.075
# 292       0.075
# 300       0.075
# 308       0.075
# 316       0.075

# %%
to_plot.set_index(['group', 'model_type'])
# Out:
#                        phase       metric  CI_lower    CI_med  CI_upper  \
# group       model_type
# Black Women EO          test  Sensitivity  0.727859  0.899129  1.000000
# White Women EO          test  Sensitivity  0.813859  0.917371  1.000000
# Black Men   EO          test  Sensitivity  0.743310  0.903388  1.000000
# White Men   EO          test  Sensitivity  0.792838  0.889175  0.972540
# overall     EO          test  Sensitivity  0.824333  0.889747  0.977894
# Black Women BL          test  Sensitivity  0.653769  0.794652  0.932574
# White Women BL          test  Sensitivity  0.687766  0.812450  0.916959
# Black Men   BL          test  Sensitivity  0.648727  0.809526  0.935933
# White Men   BL          test  Sensitivity  0.766327  0.849672  0.931140
# overall     BL          test  Sensitivity  0.767304  0.823074  0.874361
# Black Women PCE         test  Sensitivity  0.690137  0.828325  0.964304
# White Women PCE         test  Sensitivity  0.706363  0.812572  0.916875
# Black Men   PCE         test  Sensitivity  0.902901  0.967883  1.000000
# White Men   PCE         test  Sensitivity  0.888765  0.945088  0.986627
# overall     PCE         test  Sensitivity  0.850327  0.895332  0.934148
# Black Women rBL         test  Sensitivity  0.622572  0.791346  0.931643
# White Women rBL         test  Sensitivity  0.623383  0.748953  0.855055
# Black Men   rBL         test  Sensitivity  0.616592  0.778766  0.906551
# White Men   rBL         test  Sensitivity  0.726475  0.822726  0.904501
# overall     rBL         test  Sensitivity  0.725418  0.786251  0.841727
# Black Women rPCE        test  Sensitivity  0.557404  0.725939  0.895377
# White Women rPCE        test  Sensitivity  0.457536  0.602219  0.731121
# Black Men   rPCE        test  Sensitivity  0.709493  0.840919  0.938836
# White Men   rPCE        test  Sensitivity  0.713252  0.809321  0.903401
# overall     rPCE        test  Sensitivity  0.686246  0.748802  0.808279
#
#                         thresholds
# group       model_type
# Black Women EO               0.075
# White Women EO               0.075
# Black Men   EO               0.075
# White Men   EO               0.075
# overall     EO               0.075
# Black Women BL               0.075
# White Women BL               0.075
# Black Men   BL               0.075
# White Men   BL               0.075
# overall     BL               0.075
# Black Women PCE              0.075
# White Women PCE              0.075
# Black Men   PCE              0.075
# White Men   PCE              0.075
# overall     PCE              0.075
# Black Women rBL              0.075
# White Women rBL              0.075
# Black Men   rBL              0.075
# White Men   rBL              0.075
# overall     rBL              0.075
# Black Women rPCE             0.075
# White Women rPCE             0.075
# Black Men   rPCE             0.075
# White Men   rPCE             0.075
# overall     rPCE             0.075

# %%
to_plot.pivot(index=['group', 'model_type'], columns = 'phase')#,values=['metric', 'CI_lower', 'CI_med', 'CI_upper', 'thresholds'])
# Out:
#                              metric  CI_lower    CI_med  CI_upper thresholds
# phase                          test      test      test      test       test
# group       model_type
# Black Men   PCE         Sensitivity  0.902901  0.967883  1.000000      0.075
#             rPCE        Sensitivity  0.709493  0.840919  0.938836      0.075
#             BL          Sensitivity  0.648727  0.809526  0.935933      0.075
#             rBL         Sensitivity  0.616592  0.778766  0.906551      0.075
#             EO          Sensitivity  0.743310  0.903388  1.000000      0.075
# Black Women PCE         Sensitivity  0.690137  0.828325  0.964304      0.075
#             rPCE        Sensitivity  0.557404  0.725939  0.895377      0.075
#             BL          Sensitivity  0.653769  0.794652  0.932574      0.075
#             rBL         Sensitivity  0.622572  0.791346  0.931643      0.075
#             EO          Sensitivity  0.727859  0.899129  1.000000      0.075
# White Men   PCE         Sensitivity  0.888765  0.945088  0.986627      0.075
#             rPCE        Sensitivity  0.713252  0.809321  0.903401      0.075
#             BL          Sensitivity  0.766327  0.849672  0.931140      0.075
#             rBL         Sensitivity  0.726475  0.822726  0.904501      0.075
#             EO          Sensitivity  0.792838  0.889175  0.972540      0.075
# White Women PCE         Sensitivity  0.706363  0.812572  0.916875      0.075
#             rPCE        Sensitivity  0.457536  0.602219  0.731121      0.075
#             BL          Sensitivity  0.687766  0.812450  0.916959      0.075
#             rBL         Sensitivity  0.623383  0.748953  0.855055      0.075
#             EO          Sensitivity  0.813859  0.917371  1.000000      0.075
# overall     PCE         Sensitivity  0.850327  0.895332  0.934148      0.075
#             rPCE        Sensitivity  0.686246  0.748802  0.808279      0.075
#             BL          Sensitivity  0.767304  0.823074  0.874361      0.075
#             rBL         Sensitivity  0.725418  0.786251  0.841727      0.075
#             EO          Sensitivity  0.824333  0.889747  0.977894      0.075

# %%
to_plot.groupby(['group', 'model_type']).agg(['sum'])
# Out:
#                        phase       metric  CI_lower    CI_med  CI_upper  \
#                          sum          sum       sum       sum       sum
# group       model_type
# Black Men   PCE         test  Sensitivity  0.902901  0.967883  1.000000
#             rPCE        test  Sensitivity  0.709493  0.840919  0.938836
#             BL          test  Sensitivity  0.648727  0.809526  0.935933
#             rBL         test  Sensitivity  0.616592  0.778766  0.906551
#             EO          test  Sensitivity  0.743310  0.903388  1.000000
# Black Women PCE         test  Sensitivity  0.690137  0.828325  0.964304
#             rPCE        test  Sensitivity  0.557404  0.725939  0.895377
#             BL          test  Sensitivity  0.653769  0.794652  0.932574
#             rBL         test  Sensitivity  0.622572  0.791346  0.931643
#             EO          test  Sensitivity  0.727859  0.899129  1.000000
# White Men   PCE         test  Sensitivity  0.888765  0.945088  0.986627
#             rPCE        test  Sensitivity  0.713252  0.809321  0.903401
#             BL          test  Sensitivity  0.766327  0.849672  0.931140
#             rBL         test  Sensitivity  0.726475  0.822726  0.904501
#             EO          test  Sensitivity  0.792838  0.889175  0.972540
# White Women PCE         test  Sensitivity  0.706363  0.812572  0.916875
#             rPCE        test  Sensitivity  0.457536  0.602219  0.731121
#             BL          test  Sensitivity  0.687766  0.812450  0.916959
#             rBL         test  Sensitivity  0.623383  0.748953  0.855055
#             EO          test  Sensitivity  0.813859  0.917371  1.000000
# overall     PCE         test  Sensitivity  0.850327  0.895332  0.934148
#             rPCE        test  Sensitivity  0.686246  0.748802  0.808279
#             BL          test  Sensitivity  0.767304  0.823074  0.874361
#             rBL         test  Sensitivity  0.725418  0.786251  0.841727
#             EO          test  Sensitivity  0.824333  0.889747  0.977894
#
#                        thresholds
#                               sum
# group       model_type
# Black Men   PCE             0.075
#             rPCE            0.075
#             BL              0.075
#             rBL             0.075
#             EO              0.075
# Black Women PCE             0.075
#             rPCE            0.075
#             BL              0.075
#             rBL             0.075
#             EO              0.075
# White Men   PCE             0.075
#             rPCE            0.075
#             BL              0.075
#             rBL             0.075
#             EO              0.075
# White Women PCE             0.075
#             rPCE            0.075
#             BL              0.075
#             rBL             0.075
#             EO              0.075
# overall     PCE             0.075
#             rPCE            0.075
#             BL              0.075
#             rBL             0.075
#             EO              0.075

# %%
sns.set(font_scale=1.7)
sns.set_style("ticks")

to_plot = (plot_df
           .query("metric == [ 'Sensitivity', 'Specificity', 'Implied threshold']")
           .assign(metric = pd.Categorical(to_plot.metric, 
                                           categories=['Sensitivity', 'Specificity', 'Implied threshold'],
                                           ordered=True)
                  )
          )

g=sns.relplot(data = to_plot,
                x = 'model_type',
                y = 'CI_med',
                col='metric',
                row='thresholds',
                kind = 'line',
                palette = custom_palette, 
                hue='group',
                #err_style="bars",
                facet_kws= {'sharey': False, 'margin_titles': True},
                #err_kws = {'capsize': 5},
                legend=False,
                aspect=1,
              marker='X',
              markersize=14,
                linestyle='')
(g.set_xlabels('')
 .set_ylabels('')
 .set_titles(row_template="", col_template="{col_name}")
 .set_yticklabels()
 .set_xticklabels(rotation=45)
)

plt.legend(title='Group', labels=['Black Women', 'White Women', 'Black Men', 'White Men'],
           bbox_to_anchor=(-0.5,-.3)) 

sns.set(font_scale=1)
axes = g.axes.flatten()
axes[2].axhline(0.075, ls='--', linewidth=3, color='grey')
axes[5].axhline(0.2, ls='--', linewidth=3, color='grey')

# if save_plots:
#     output_path = os.path.join(args['plot_path'], 'discr_calib_2.png')
#     g.savefig(output_path)

# %%
sns.set(font_scale=1.7)
sns.set_style("ticks")

to_plot = plot_df.query("metric == ['AUC', 'Sensitivity (t=7.5%)', 'Specificity (t=7.5%)', 'Implied threshold (t=7.5%)']")
to_plot = to_plot.assign(metric = pd.Categorical(to_plot.metric, 
                      categories=['AUC', 'Sensitivity (t=7.5%)', 'Specificity (t=7.5%)', 'Implied threshold (t=7.5%)'],
                      ordered=True)
                        )
#to_plot = to_plot.query("model_type != ['EO1', 'EO2', 'EO4']").rename(columns={'EO3': 'EO'})

g=sns.relplot(data = to_plot,
                x = 'model_type',
                y = 'CI_med',
                col='metric',
                #row='y_axis',
                kind = 'line',
                palette = custom_palette, 
                hue='group',
                #err_style="bars",
                facet_kws= {'sharey': False, 'margin_titles': True},
                #err_kws = {'capsize': 5},
                legend=False,
                aspect=1,
              marker='X',
              markersize=14,
                linestyle='')
(g.set_xlabels('')
 .set_ylabels('')
 .set_titles(row_template="", col_template="{col_name}")
 .set_yticklabels()
 .set_xticklabels(rotation=45)
)

# plt.legend(title='Group', labels=['Black Women', 'White Women', 'Black Men', 'White Men'],
#            bbox_to_anchor=(-0.5,-.3)) 

sns.set(font_scale=1)
axes = g.axes.flatten()
axes[-1].axhline(0.075, ls='--', linewidth=3, color='grey')

# if save_plots:
#     output_path = os.path.join(args['plot_path'], 'discr_calib_2.png')
#     g.savefig(output_path)

# %%
sns.set(font_scale=1.7)
sns.set_style("ticks")

#g=sns.relplot(data = plot_df.query("metric == ['AUPRC', 'sensitivity (t=20%)', 'specificity (t=20%)', 'observation rate (t=20%)']"),
to_plot = plot_df.query("metric == ['AUPRC', 'Sensitivity (t=20%)', 'Specificity (t=20%)', 'Implied threshold (t=20%)']")
to_plot = to_plot.assign(metric = pd.Categorical(to_plot.metric, 
                      categories=['AUPRC', 'Sensitivity (t=20%)', 'Specificity (t=20%)', 'Implied threshold (t=20%)'],
                      ordered=True)
                        )

g=sns.relplot(data = to_plot,               
              x = 'model_type',
              y = 'CI_med',
              col='metric',
            #row='y_axis',
              kind = 'line',
              palette = custom_palette, 
              hue='group',
              #err_style="bars",
              facet_kws= {'sharey': False, 'margin_titles': True},
              #err_kws = {'capsize': 5},
              legend=False,
              aspect=1,
              marker='X',
              markersize=14,
              linestyle='')
(g.set_xlabels('')
 .set_ylabels('')
 .set_titles(row_template="", col_template="{col_name}")
 .set_yticklabels()
 .set_xticklabels(rotation=45)
)

plt.legend(title='Group', labels=args['grp_label_dict'].values(),
           bbox_to_anchor=(-1,-.3)) #bbox_to_anchor=(1, 1))

#plt.legend(bbox_to_anchor=(-1.3,-.3)) 

sns.set(font_scale=1)
axes = g.axes.flatten()
axes[-1].axhline(0.2, ls='--', linewidth=3, color='grey')


if save_plots:
    output_path = os.path.join(args['plot_path'], 'discr_calib_2.png')
    g.savefig(output_path)

# %%
(plot_df
 .query("(phase=='test') ")
 .drop(columns=['model_id', 'phase', 'CI_lower', 'CI_upper'])
 .pivot(index=['metric', 'group'], columns=['model_type'], values='CI_med')
 .tail(30)
)

# %%
(plot_df
 .query("(phase=='test') & (metric=='AUPRC') ")
 .drop(columns=['model_id', 'phase', 'CI_lower', 'CI_upper'])
 .groupby(['metric', 'model_type', 'group']).sum()
 .head(30)
)

# %%
plot_df1 = plot_df.assign(value = lambda x: x.CI_med.round(3).astype(str) + 
               ' (' + x.CI_lower.round(3).astype(str)+', ' + 
               x.CI_upper.round(3).astype(str) + ')')


a=(plot_df1
 .query("phase=='test'")
 .drop(columns=['model_id', 'phase', 'CI_lower', 'CI_med', 'CI_upper'])
 .pivot(index=['metric', 'group'], columns='model_type')
 
)

a.head(50)
