# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import logging
import sys
import copy
import configargparse as argparse
from prediction_utils.pytorch_utils.metrics import StandardEvaluator, FairOVAEvaluator
from prediction_utils.util import yaml_write

#import train_utils
import yaml

parser = argparse.ArgumentParser()
# parser.add_argument('--experiment_name', type=str)
# parser.add_argument('--cohort_path', type=str) 
# parser.add_argument('--result_path', type=str)
# parser.add_argument('--base_config_path', type=str)
args = {'experiment_name': 'original_pce',
       'cohort_path':      '/labs/shahlab/projects/agataf/data/cohorts/pooled_cohorts/cohort/all_cohorts.csv',
       'base_config_path': '/labs/shahlab/projects/agataf/data/cohorts/pooled_cohorts/experiments/basic_config.yaml',
       'result_path':      '/labs/shahlab/projects/agataf/data/cohorts/pooled_cohorts/experiments/original_pce/performance'}


# parser.set_defaults(
#     save_outputs=False,
#     run_evaluation=True,
#     run_evaluation_group_standard=True,
#     run_evaluation_group_fair_ova=True,
#     print_debug=True,
#     save_model_weights=False,
#     data_query = '',
#     num_epochs = 0
# )

# args = parser.parse_args()
# args = copy.deepcopy(args.__dict__)

os.makedirs(args['result_path'], exist_ok=True)

df = pd.read_csv(args['cohort_path'])
df = df.assign(sysbp = lambda x: x.rxsbp+x.unrxsbp,
         rxbp = lambda x: (x.rxsbp>0).astype(int))
config_dict = yaml.load(open(args['base_config_path']), Loader=yaml.FullLoader)

coefs = {1: [17.114, 0, 0.94, 0, -18.920, 4.475, 29.291, -6.432, 27.820, -6.087, 0.691, 0, 0.874],
              2: [-29.799, 4.884, 13.54, -3.114, -13.578, 3.149, 2.019, 0, 1.957, 0, 7.574, -1.665, 0.661],
              3: [2.469, 0, 0.302, 0, -0.307, 0, 1.916, 0, 1.809, 0, 0.549, 0, 0.645],
              4: [12.344, 0, 11.853, -2.664, -7.990, 1.769, 1.797, 0, 1.7864, 0, 7.837, -1.795, 0.658]}
mean_risk = {1: 86.61, 2:-29.18, 3:19.54, 4:61.18}
baseline_survival = {1:0.9533, 2:0.9665, 3:0.8954, 4:0.9144}

   vars = matrix(c(#log(age),
                    #log(age)^2,
                    #log(totchol),
                   # log(age)*log(totchol),
                   # log(hdl),
                   # log(age)*log(hdl),
                   # rxbp*log(sysbp),
                   # rxbp*log(age)*log(sysbp),
                    (1-rxbp)*log(sysbp),
                    (1-rxbp)*log(age)*log(sysbp),
                    cursmoke,
                    log(age)*cursmoke,
                    dm), ncol=13)
    
data_df = (pd.DataFrame({'log(age)': np.log(df.age),
                    'log(age)^2': np.log(df.age)**2,
                    'log(totchol)': np.log(df.totchol),
                    'log(age)*log(totchol)': np.log(df.age)*np.log(df.totchol),
                    'log(hdlc)': np.log(df.hdlc),
                    'log(age)*log(hdlc)': np.log(df.age)*np.log(df.hdlc),
                    'rxbp*log(sysbp)': df.rxbp*np.log(df.sysbp),
                    'rxbp*log(age)*log(sysbp)': df.rxbp*np.log(df.age)*np.log(df.sysbp),
                    '(1-rxbp)*log(sysbp)': (1-df.rxbp)*np.log(df.sysbp),
                    '(1-rxbp)*log(age)*log(sysbp)': (1-df.rxbp)*np.log(df.age)*np.log(df.sysbp),
                    'cursmoke': df.cursmoke,
                    'log(age)*cursmoke': df.cursmoke*np.log(df.age),
                    'diabt126': df.diabt126
                   }
                  )#.replace(float('-inf'), 0)
           # TODO: a warning is popping up here (RuntimeWarning: divide by zero encountered in log)
     )

risks = []
for group in [1,2,3,4]:
    relative_risk = (data_df
                     .iloc[np.where(df.grp==group)]
                     .multiply(coefs[group])
                     .sum(axis=1)
                     .sub(mean_risk[group])
                     .transform(np.exp)
                    )
    print(min(relative_risk))
    print(relative_risk.isna().sum())
    risk = 1 - pow(baseline_survival[group], relative_risk)
    risks.append(risk)
    
risks = pd.concat(risks)
# Out:
# nan
# 5354
# 0.0
# 0
# 0.0
# 0
# 0.0
# 0
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/pandas/core/series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# Out:
#        rxsbp  unrxsbp  sysbp  rxbp
# 0        0.0    130.0  130.0     0
# 1        0.0    110.0  110.0     0
# 2        0.0    112.0  112.0     0
# 3        0.0    131.0  131.0     0
# 4      133.0      0.0  133.0     1
# ...      ...      ...    ...   ...
# 25614  114.5      0.0  114.5     1
# 25615    0.0    128.0  128.0     0
# 25616    0.0    124.5  124.5     0
# 25617  157.0      0.0  157.0     1
# 25618  142.5      0.0  142.5     1
#
# [25619 rows x 4 columns]

# %%
                     (data_df
                     .iloc[np.where(df.grp==1)]
                     .multiply(coefs[1])
                     #.sum(axis=1)
                     #.sub(mean_risk[1])
                     #.transform(np.exp)
                    )
# Out:
#         log(age)  log(age)^2  log(totchol)  log(age)*log(totchol)  log(hdlc)  \
# 4904   72.086352         0.0      5.226932                    0.0 -74.757531
# 4915   71.571606         0.0      4.988654                    0.0 -74.390141
# 5178   72.586066         0.0      4.809562                    0.0 -75.818744
# 5209   74.003206         0.0      5.029677                    0.0 -84.711213
# 5370   74.450657         0.0      5.118960                    0.0 -76.823582
# ...          ...         ...           ...                    ...        ...
# 25231  70.905608         0.0      5.044017                    0.0 -77.147008
# 25232  72.951503         0.0      4.917242                    0.0 -75.117923
# 25233  69.782976         0.0      4.810914                    0.0 -73.633240
# 25234  74.339886         0.0      5.151801                    0.0 -66.718741
# 25235  69.782976         0.0      4.575482                    0.0 -70.260784
#
#        log(age)*log(hdlc)  log(rxsbp)  log(age)*log(rxsbp)  log(unrxsbp)  \
# 4904            74.478064        -inf                  inf    139.722228
# 4915            73.582836        -inf                  inf    132.955216
# 5178            76.058932        -inf                  inf    132.004012
# 5209            86.638678        -inf                  inf    133.647865
# 5370            79.046649  144.535676          -138.071454          -inf
# ...                   ...         ...                  ...           ...
# 25231           75.599697        -inf                  inf    135.839549
# 25232           75.735273        -inf                  inf    136.873869
# 25233           71.013967  147.057974          -131.673498          -inf
# 25234           68.547262  151.531742          -144.539256          -inf
# 25235           67.761475  142.348765          -127.456943          -inf
#
#        log(age)*log(unrxsbp)  cursmoke  log(age)*cursmoke  diabt126
# 4904             -128.769556     0.000                0.0     0.000
# 4915             -121.658033     0.000                0.0     0.874
# 5178             -122.499704     0.000                0.0     0.000
# 5209             -126.446616     0.691                0.0     0.000
# 5370                     inf     0.000                0.0     0.000
# ...                      ...       ...                ...       ...
# 25231            -123.140656     0.000                0.0     0.000
# 25232            -127.658413     0.691                0.0     0.000
# 25233                    inf     0.000                0.0     0.000
# 25234                    inf     0.000                0.0     0.000
# 25235                    inf     0.000                0.0     0.874
#
# [5354 rows x 13 columns]

# %%
from lifelines import KaplanMeierFitter, LogNormalFitter, WeibullFitter

def censoring_weights(df, model_type = 'KM'):

    if model_type == 'KM':
        censoring_model = KaplanMeierFitter()
    else:
        raise ValueError("censoring_model not defined")
    
    censoring_model.fit(df.query('is_train==1').event_time, 1.0*~df.query('is_train==1').event_indicator)
    
    weights = 1 / censoring_model.survival_function_at_times(df.event_time_10yr.values - 1e-5)
    weights_dict = dict(zip(df.index.values, weights.values))
    return weights_dict

def get_censoring(df, by_group=True, model_type='KM'):
    
    if by_group:
        weight_dict = {}
        for group in [1, 2, 3, 4]:
            group_df = df.query('grp==@group')
            group_weights_dict = censoring_weights(group_df, model_type)
            weight_dict.update(group_weights_dict)

    else:
        weight_dict = censoring_weights(cohort, censoring_model_type)

    weights = pd.Series(weight_dict, name='weights') 
    return weights

df = df.assign(is_train = lambda x: np.where((x.fold_id != config_dict.get('fold_id')) & (x.fold_id != "test") 
                                                         & (x.fold_id != "eval"),
                                                         1, 0))
all_weights = get_censoring(df, by_group = True, model_type = 'KM')

# %%
risks.isna().sum()
# Out:
# 5354

# %%
output_df_eval = (df
           .rename(columns={'person_id': 'row_id',
                            'fold_id': 'phase',
                            'grp': 'group'})
           .assign(labels = lambda x: x.ascvd_10yr.astype(int),
                   pred_probs = risks,
                   weights = all_weights)
           .filter(['phase', 'pred_probs', 'labels', 'row_id', 'weights', 'group'])
            )

output_df_eval.to_parquet(
    os.path.join(args['result_path'], "output_df.parquet"),
    index=False,
    engine="pyarrow"
)

evaluator = StandardEvaluator(threshold_metrics = config_dict['logging_threshold_metrics'],
                              thresholds = config_dict['logging_thresholds'],
                              metrics = ['auc', 'auprc', 'loss_bce', 
                                         'ace_rmse_logistic_log',
                                         'ace_abs_logistic_log']
                             )

eval_general_args = {'df': output_df_eval,
                     'label_var': 'labels',
                     'pred_prob_var': 'pred_probs',
                     'weight_var': 'weights', 
                     'strata_vars': ['phase'],
                     'group_var_name': 'group'}

result_df_overall = evaluator.get_result_df(**eval_general_args)


results_df = (result_df_overall
              .assign(group='all')
              .rename(columns={'performance_overall': 'performance'})
              #.append(result_df_by_group)
)

result_df_overall.to_parquet(
    os.path.join(args['result_path'], "result_df_group_standard_eval.parquet"),
    engine="pyarrow",
    index=False
)
# Out:
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py:160: UserWarning: Error in metric_fn, filling with default_value
#   warnings.warn("Error in metric_fn, filling with default_value")
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py:160: UserWarning: Error in metric_fn, filling with default_value
#   warnings.warn("Error in metric_fn, filling with default_value")
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py:160: UserWarning: Error in metric_fn, filling with default_value
#   warnings.warn("Error in metric_fn, filling with default_value")
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py:160: UserWarning: Error in metric_fn, filling with default_value
#   warnings.warn("Error in metric_fn, filling with default_value")
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py:160: UserWarning: Error in metric_fn, filling with default_value
#   warnings.warn("Error in metric_fn, filling with default_value")
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py:160: UserWarning: Error in metric_fn, filling with default_value
#   warnings.warn("Error in metric_fn, filling with default_value")
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py:160: UserWarning: Error in metric_fn, filling with default_value
#   warnings.warn("Error in metric_fn, filling with default_value")
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py:160: UserWarning: Error in metric_fn, filling with default_value
#   warnings.warn("Error in metric_fn, filling with default_value")
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py:160: UserWarning: Error in metric_fn, filling with default_value
#   warnings.warn("Error in metric_fn, filling with default_value")
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py:160: UserWarning: Error in metric_fn, filling with default_value
#   warnings.warn("Error in metric_fn, filling with default_value")
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py:160: UserWarning: Error in metric_fn, filling with default_value
#   warnings.warn("Error in metric_fn, filling with default_value")
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py:160: UserWarning: Error in metric_fn, filling with default_value
#   warnings.warn("Error in metric_fn, filling with default_value")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-e8ee821f61dd> in <module>
#      29                      'group_var_name': 'group'}
#      30
# ---> 31 result_df_overall = evaluator.get_result_df(**eval_general_args)
#      32
#      33
#
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py in get_result_df(self, df, strata_vars, weight_var, label_var, pred_prob_var, group_var_name)
#     556             strata_vars = []
#     557
# --> 558         result_df_by_group = self.evaluate(
#     559             df,
#     560             strata_vars=strata_vars + [group_var_name],
#
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py in evaluate(self, df, strata_vars, result_name, weight_var, label_var, pred_prob_var)
#     516         else:
#     517             result_df = df_dict_concat(
# --> 518                 {
#     519                     metric: df.groupby(strata_vars)
#     520                     .apply(
#
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py in <dictcomp>(.0)
#     517             result_df = df_dict_concat(
#     518                 {
# --> 519                     metric: df.groupby(strata_vars)
#     520                     .apply(
#     521                         lambda x: metric_func(
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     857         with option_context("mode.chained_assignment", None):
#     858             try:
# --> 859                 result = self._python_apply_general(f, self._selected_obj)
#     860             except TypeError:
#     861                 # gh-20949
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     890             data after applying f
#     891         """
# --> 892         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     893
#     894         return self._wrap_applied_output(
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     211             # group might be modified
#     212             group_axes = group.axes
# --> 213             res = f(group)
#     214             if not _is_indexed_like(res, group_axes):
#     215                 mutated = True
#
# /labs/shahlab/projects/agataf/prediction_utils/prediction_utils/pytorch_utils/metrics.py in <lambda>(x)
#     523                         )
#     524                         if weight_var is None
# --> 525                         else metric_func(
#     526                             x[label_var].values,
#     527                             x[pred_prob_var].values,
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in average_precision_score(y_true, y_score, average, pos_label, sample_weight)
#     214     average_precision = partial(_binary_uninterpolated_average_precision,
#     215                                 pos_label=pos_label)
# --> 216     return _average_binary_score(average_precision, y_true, y_score,
#     217                                  average, sample_weight=sample_weight)
#     218
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/sklearn/metrics/_base.py in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      75
#      76     if y_type == "binary":
# ---> 77         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      78
#      79     check_consistent_length(y_true, y_score, sample_weight)
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in _binary_uninterpolated_average_precision(y_true, y_score, pos_label, sample_weight)
#     195     def _binary_uninterpolated_average_precision(
#     196             y_true, y_score, pos_label=1, sample_weight=None):
# --> 197         precision, recall, _ = precision_recall_curve(
#     198             y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     199         # Return the step function integral
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in precision_recall_curve(y_true, probas_pred, pos_label, sample_weight)
#     673
#     674     """
# --> 675     fps, tps, thresholds = _binary_clf_curve(y_true, probas_pred,
#     676                                              pos_label=pos_label,
#     677                                              sample_weight=sample_weight)
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     543     y_score = column_or_1d(y_score)
#     544     assert_all_finite(y_true)
# --> 545     assert_all_finite(y_score)
#     546
#     547     if sample_weight is not None:
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/sklearn/utils/validation.py in assert_all_finite(X, allow_nan)
#     115     allow_nan : bool
#     116     """
# --> 117     _assert_all_finite(X.data if sp.issparse(X) else X, allow_nan)
#     118
#     119
#
# /labs/shahlab/envs/agataf/miniconda3/envs/utility/lib/python3.8/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      94                 not allow_nan and not np.isfinite(X).all()):
#      95             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 96             raise ValueError(
#      97                     msg_err.format
#      98                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
evaluator.get_result_df(**eval_general_args)

# %%
evaluator = FairOVAEvaluator(threshold_metrics = config_dict['logging_threshold_metrics'],
                             thresholds = config_dict['logging_thresholds'])
    
eval_fair_args = {'df': output_df_eval,
                  'label_var': 'labels',
                  'pred_prob_var': 'pred_probs',
                  'weight_var': 'weights',
                  'group_var_name': 'group',
                  'strata_vars': ['phase']}
        
result_df_group_fair_ova = evaluator.get_result_df(**eval_fair_args)

result_df_group_fair_ova.to_parquet(
    os.path.join(args['result_path'], "result_df_group_fair_ova.parquet"),
    engine="pyarrow",
    index=False
)
