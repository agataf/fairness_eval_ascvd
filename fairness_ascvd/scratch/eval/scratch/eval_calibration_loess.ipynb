# %%
library(dplyr)
library(ggplot2)


args.calib_model_id = 'loess'
args.base_path = '/labs/shahlab/projects/agataf/data/cohorts/pooled_cohorts'
args.experiment_name = 'apr14_thr'
args.cohort_path = '/labs/shahlab/projects/agataf/data/cohorts/pooled_cohorts/cohort/all_cohorts.csv'
args.n_bootstrap = 100
args.eval_fold = 'test'

aggregate_path = file.path(args.base_path, 'experiments', 
                              args.experiment_name, 'performance',
                              'all')
preds_path = file.path(aggregate_path, 'predictions.csv')
preds = read.csv(preds_path)

if (!('fold_id' %in% colnames(preds))) {
    preds = preds %>% mutate(fold_id=0)
}
if (!('model_id' %in% colnames(preds))) {
    preds = preds %>% mutate(model_id=0)
}

df_to_calibrate <- preds %>% filter(phase==args.eval_fold)

lin_calibs=c()
thr_calibs=c()
for (iter_idx in 1:args.n_bootstrap) {
    for (group in 1:4) {
        for (model_id in unique(preds$model_id)) {
            group_df = df_to_calibrate %>% filter(group==!!group, model_id==!!model_id)
            max_pred_prob = group_df$pred_probs %>% max
            for (fold_id in unique(group_df$fold_id)) {
                df <- group_df %>% filter(fold_id==!!fold_id)
                df = sample(df, nrow(df), replace = TRUE)
                loess_fit = loess(labels ~ pred_probs, df, weights)
                thr_calib = predict(loess_fit, data.frame(pred_probs = c(0.075, 0.2)), se = FALSE)
                lin_range = c(1e-15, seq(0.025, as.integer(max_pred_prob/0.025)*0.025, length.out = as.integer((max_pred_prob)/0.025)))
                lin_calib = predict(loess_fit, data.frame(pred_probs = lin_range), se = FALSE)

                lin_calib_frame = data.frame(pred_probs = lin_range,
                                             calibration_density = lin_calib) %>% 
                                  mutate(group = group, 
                                         fold_id = fold_id,
                                         phase = args.eval_fold,
                                         model_type = as.character(unique(preds$model_type)[1]),
                                         model_id = args.calib_model_id)
                
                thr_calib_frame = data.frame(pred_probs = c(0.075, 0.2),
                                             calibration_density = thr_calib) %>% 
                                  mutate(group = group, 
                                         fold_id = fold_id,
                                         phase = args.eval_fold,
                                         model_type = as.character(unique(preds$model_type)[1]),
                                         model_id = args.calib_model_id)


                lin_calibs = rbind(lin_calibs, lin_calib_frame)
                thr_calibs = rbind(thr_calibs, thr_calib_frame)
    
            }
        }
    } 
}

output_path = file.path(aggregate_path, 'calibration', args.calib_model_id)

if (!dir.exists(output_path)) {
    dir.create(output_path, recursive=TRUE)
}

write.csv(lin_calibs, file.path(output_path, 'calibration_sensitivity_test_raw.csv'))
write.csv(thr_calibs, file.path(output_path, 'calibration_sensitivity_thresholds_raw.csv'))

# %%
lin_calibs
# Out:
#        pred_probs calibration_density group fold_id phase model_type model_id
# 1      1.00e-15           NA          1     1       test  eqodds_thr loess
# 2      2.50e-02   0.02839258          1     1       test  eqodds_thr loess
# 3      5.00e-02   0.04073151          1     1       test  eqodds_thr loess
# 4      7.50e-02   0.03776487          1     1       test  eqodds_thr loess
# 5      1.00e-01   0.06862059          1     1       test  eqodds_thr loess
# 6      1.25e-01   0.11115922          1     1       test  eqodds_thr loess
# 7      1.50e-01   0.14841823          1     1       test  eqodds_thr loess
# 8      1.75e-01   0.17144685          1     1       test  eqodds_thr loess
# 9      2.00e-01   0.19133787          1     1       test  eqodds_thr loess
# 10     2.25e-01   0.21123448          1     1       test  eqodds_thr loess
# 11     2.50e-01   0.23124530          1     1       test  eqodds_thr loess
# 12     2.75e-01   0.25147898          1     1       test  eqodds_thr loess
# 13     3.00e-01   0.27204416          1     1       test  eqodds_thr loess
# 14     3.25e-01   0.29304948          1     1       test  eqodds_thr loess
# 15     3.50e-01   0.31460358          1     1       test  eqodds_thr loess
# 16     3.75e-01   0.33681509          1     1       test  eqodds_thr loess
# 17     4.00e-01   0.35979266          1     1       test  eqodds_thr loess
# 18     4.25e-01   0.38364492          1     1       test  eqodds_thr loess
# 19     4.50e-01   0.40848051          1     1       test  eqodds_thr loess
# 20     4.75e-01   0.43440808          1     1       test  eqodds_thr loess
# 21     5.00e-01   0.46153625          1     1       test  eqodds_thr loess
# 22     5.25e-01   0.48997367          1     1       test  eqodds_thr loess
# 23     5.50e-01   0.51982898          1     1       test  eqodds_thr loess
# 24     5.75e-01   0.55121082          1     1       test  eqodds_thr loess
# 25     6.00e-01   0.58422783          1     1       test  eqodds_thr loess
# 26     6.25e-01   0.61898863          1     1       test  eqodds_thr loess
# 27     6.50e-01   0.65560189          1     1       test  eqodds_thr loess
# 28     6.75e-01   0.69417622          1     1       test  eqodds_thr loess
# 29     7.00e-01   0.73482027          1     1       test  eqodds_thr loess
# 30     7.25e-01   0.77764269          1     1       test  eqodds_thr loess
# ...    ...        ...                 ...   ...     ...   ...        ...
# 104277 0.025      0.02472182          1     6       test  eqodds_thr loess
# 104278 0.050      0.04592651          1     6       test  eqodds_thr loess
# 104279 0.075      0.04512938          1     6       test  eqodds_thr loess
# 104280 0.100      0.07115555          1     6       test  eqodds_thr loess
# 104281 0.125      0.10926898          1     6       test  eqodds_thr loess
# 104282 0.150      0.14156809          1     6       test  eqodds_thr loess
# 104283 0.175      0.15935885          1     6       test  eqodds_thr loess
# 104284 0.200      0.17630506          1     6       test  eqodds_thr loess
# 104285 0.225      0.19439794          1     6       test  eqodds_thr loess
# 104286 0.250      0.21366002          1     6       test  eqodds_thr loess
# 104287 0.275      0.23411385          1     6       test  eqodds_thr loess
# 104288 0.300      0.25578195          1     6       test  eqodds_thr loess
# 104289 0.325      0.27868685          1     6       test  eqodds_thr loess
# 104290 0.350      0.30285109          1     6       test  eqodds_thr loess
# 104291 0.375      0.32829719          1     6       test  eqodds_thr loess
# 104292 0.400      0.35504771          1     6       test  eqodds_thr loess
# 104293 0.425      0.38312515          1     6       test  eqodds_thr loess
# 104294 0.450      0.41255207          1     6       test  eqodds_thr loess
# 104295 0.475      0.44335098          1     6       test  eqodds_thr loess
# 104296 0.500      0.47554444          1     6       test  eqodds_thr loess
# 104297 0.525      0.50915495          1     6       test  eqodds_thr loess
# 104298 0.550      0.54420507          1     6       test  eqodds_thr loess
# 104299 0.575      0.58071732          1     6       test  eqodds_thr loess
# 104300 0.600      0.61871424          1     6       test  eqodds_thr loess
# 104301 0.625      0.65821836          1     6       test  eqodds_thr loess
# 104302 0.650      0.69925220          1     6       test  eqodds_thr loess
# 104303 0.675      0.74183831          1     6       test  eqodds_thr loess
# 104304 0.700      0.78599922          1     6       test  eqodds_thr loess
# 104305 0.725      0.83175746          1     6       test  eqodds_thr loess
# 104306 0.750              NA          1     6       test  eqodds_thr loess
